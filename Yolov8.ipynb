# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
 # pip install labelme

# %%
## Conver json files to YOLODATASET

#!python /content/drive/MyDrive/Colab\ Notebooks/Labelme2YOLO.py --json_dir '/content/drive/MyDrive/Colab Notebooks/Leishmania-Data_RAW/LEISHMANIA_NEW_LABEL/Leishmania-Data_RAW/Labels' --val_size 0.2

# %%
! pip install ultralytics

# %%
# TRAIN YOLO
from ultralytics import YOLO

# Load a pretrained YOLO model
model = YOLO("yolov8l.pt")

# Train the model
model.train(data="/content/drive/MyDrive/Colab Notebooks/Leishmania-Data_RAW/LEISHMANIA_NEW_LABEL/Leishmania-Data_RAW/Labels/YOLODataset/dataset.yaml", epochs=50)

# Evaluate model performance on the validation set
metrics = model.val()

# Print evaluation metrics
print(metrics)
print("--------------------------------------------------")
# Out:
# Ultralytics YOLOv8.2.74 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (NVIDIA L4, 22700MiB)
# ...

# %%
from PIL import Image
import matplotlib.pyplot as plt

img_path = ["deneme.jpg","deneme2.jpg","deneme3.jpg","deneme4.jpg","deneme5.jpeg"]

results = model(img_path)

for i, r in enumerate(results):
 im_bgr = r.plot()
 im_rgb = Image.fromarray(im_bgr[..., ::-1])
 plt.figure(figsize=(8, 6))
 plt.imshow(im_rgb)
 plt.title(f'Result {i+1}')
 plt.axis('off')
 plt.show()
# Out:
# 0: 640x640 44 1s, 29.8ms
# 1: 640x640 2 1s, 29.8ms
# 2: 640x640 18 1s, 29.8ms
# 3: 640x640 26 1s, 29.8ms
# 4: 640x640 8 1s, 29.8ms
# Speed: 2.4ms preprocess, 29.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
